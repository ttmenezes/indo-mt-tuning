# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
steps = np.array([
    25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375,
    400, 425, 450, 475, 500, 525, 550, 575, 600, 625, 650, 675, 700, 725,
    750, 775, 800, 825, 850, 875, 900, 925, 950, 975, 1000, 1025, 1050,
    1075, 1100, 1125, 1150, 1175, 1200, 1225, 1250, 1275, 1300, 1325, 1350,
    1375, 1400, 1425, 1450, 1475, 1500, 1525, 1550, 1575, 1600, 1625, 1650,
    1675, 1700, 1725, 1750, 1775, 1800, 1825, 1850, 1875, 1900, 1925, 1950,
    1975, 2000, 2025, 2050, 2075, 2100, 2125, 2150, 2175, 2200, 2225, 2250,
    2275, 2300, 2325, 2350, 2375, 2400, 2425, 2450, 2475, 2500, 2525, 2550,
    2575, 2600, 2625, 2650, 2675, 2700, 2725, 2750, 2775, 2800, 2825, 2850,
    2875, 2900, 2925, 2950, 2975
])

training_loss = np.array([
    3.757200, 2.357000, 2.259200, 2.024500, 2.165200, 1.830200, 1.908000,
    1.731700, 1.940900, 1.837000, 1.738300, 1.674700, 1.776600, 1.631900,
    1.402200, 1.258100, 1.101400, 1.367300, 1.147800, 1.249700, 1.167500,
    1.252500, 1.158200, 1.219900, 1.090900, 1.224100, 1.011300, 1.202100,
    1.120300, 1.653400, 1.001400, 1.345400, 1.225400, 1.286700, 0.830100,
    1.400400, 1.090900, 1.237200, 0.993900, 1.235200, 0.901800, 1.347600,
    1.060200, 1.325800, 0.860500, 0.719900, 0.637800, 0.709500, 0.570700,
    0.772100, 0.712300, 0.676400, 0.758400, 0.751300, 0.569200, 0.597800,
    0.737900, 0.775600, 0.649800, 1.064600, 0.483300, 0.971700, 0.510600,
    0.950000, 0.483200, 1.078500, 0.530800, 1.008300, 0.636300, 1.025700,
    0.523100, 1.036900, 0.559300, 0.828900, 0.487900, 0.287000, 0.313200,
    0.329300, 0.403900, 0.350200, 0.308300, 0.306700, 0.341100, 0.320600,
    0.380300, 0.320800, 0.431200, 0.322300, 0.349200, 0.650000, 0.217700,
    0.560300, 0.213000, 0.527300, 0.209300, 0.560500, 0.213400, 0.572300,
    0.227500, 0.575500, 0.219700, 0.583600, 0.203100, 0.440400, 0.320700,
    0.156500, 0.264000, 0.169200, 0.261300, 0.166200, 0.270200, 0.156700,
    0.292500, 0.170200, 0.257300, 0.162900, 0.275600, 0.162000, 0.271900
])

validation_loss = np.array([
    3.502915, 3.150830, 2.950760, 2.878858, 2.911474, 2.871620, 2.778886,
    2.902276, 2.869655, 2.958750, 2.787595, 2.736640, 2.662224, 2.741445,
    2.728358, 2.657672, 2.669897, 2.604192, 2.608799, 2.618351, 2.686294,
    2.569199, 2.614284, 2.565600, 2.542626, 2.620116, 2.530109, 2.531610,
    2.602391, 2.472151, 2.596940, 2.476447, 2.565812, 2.495643, 2.553602,
    2.522796, 2.516059, 2.542777, 2.564247, 2.514120, 2.556894, 2.463492,
    2.528087, 2.478244, 2.449562, 2.613694, 2.490924, 2.498526, 2.509300,
    2.605528, 2.452630, 2.499007, 2.472976, 2.514949, 2.494626, 2.497071,
    2.425855, 2.464590, 2.446090, 2.476257, 2.608282, 2.553312, 2.602798,
    2.511920, 2.565111, 2.529064, 2.608358, 2.556112, 2.544660, 2.518339,
    2.592295, 2.545875, 2.569182, 2.580351, 2.545109, 2.687906, 2.646364,
    2.671648, 2.650369, 2.634046, 2.646616, 2.639580, 2.610605, 2.643788,
    2.655057, 2.599612, 2.693126, 2.590572, 2.684025, 2.703416, 2.948718,
    2.829717, 2.842394, 2.812278, 2.861738, 2.878063, 2.846645, 2.848086,
    2.874330, 2.845997, 2.821769, 2.817191, 2.868536, 2.881542, 2.943413,
    3.061152, 3.050993, 3.050482, 3.089737, 3.076097, 3.073034, 3.072956,
    3.090230, 3.108420, 3.075379, 3.091989, 3.083249, 3.092247, 3.077336
])

# Plotting the data
plt.figure(figsize=(12, 6))  # Adjust figure size for better readability
plt.plot(steps, training_loss, label='Training Loss', color='blue')
plt.plot(steps, validation_loss, label='Validation Loss', color='red')

# Adding labels and title
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)  # Add grid for better readability

# Customize the plot for enhanced visual appeal
plt.xlim(steps.min(), steps.max())  # Set x-axis limits to the range of steps
plt.ylim(0, max(training_loss.max(), validation_loss.max()) * 1.1) #Adjust the y axis to not have the plot lines right on the top and bottom
plt.xticks(np.arange(steps.min(), steps.max()+1, 200)) #Only show xticks every 200 steps

# Show the plot
plt.show()
