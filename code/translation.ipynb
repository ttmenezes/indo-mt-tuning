# %%
# translate x -> idn

# load in test set

# %%
# for each model in list, translate from javanese to idn and from sundanese to idn
# save results to csv - input, model output, reference output

# models:
# - Llama 1B
# - Llama 8B
# - Cohere Aya 8B
# - Cohere Aya 32B
# - GPT-4o-mini
# - Llama 32B
# - Llama 70B
# - Llama 405B
# - Claude Sonnet 3.5
# - GPT-4o
# - o3-mini
# - Deepseek R1 - potentially good for complex sentences

# %%
import pandas as pd

def load_translation_pairs():
    # Read the CSV file
    df = pd.read_csv('../datasets/test.csv')
    
    # Iterate over the javanese and indonesian columns
    for javanese, indonesian in zip(df['javanese'], df['indonesian']):
        yield {
            'source': javanese,
            'target': indonesian
        }

# Example usage:
translation_pairs = load_translation_pairs()

# You can then iterate over the pairs like this:
for pair in translation_pairs:
    source_text = pair['source']      # Javanese text
    reference = pair['target']        # Indonesian text
    
    # Run your translation operation here on source_text
    # translated_text = your_translation_function(source_text)
    
    # Compare translated_text with reference
    # comparison_result = compare_translations(translated_text, reference)

# %% [markdown]
# ### Llama 3.2 1B

# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

def translate_llama_1B(source_text):
    completion = client.chat.completions.create(
    #   model="meta/llama-3.1-405b-instruct",
      model="meta/llama-3.2-1b-instruct",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      temperature=0,
      top_p=0.7,
      max_tokens=1024,
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### Llama 3.1 8B

# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

def translate_llama_8B(source_text):
    completion = client.chat.completions.create(
      model="meta/llama-3.1-8b-instruct",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      temperature=0,
      top_p=0.7,
      max_tokens=1024,
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### Llama 3.3 70B

# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

def translate_llama_70B(source_text):
    completion = client.chat.completions.create(
      model="meta/llama-3.3-70b-instruct",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      temperature=0,
      top_p=0.7,
      max_tokens=1024,
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### Llama 3.1 405B

# %%
from openai import AsyncOpenAI

# Create async client
client = AsyncOpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

async def translate_llama_405B(source_text):
    completion = await client.chat.completions.create(
      model="meta/llama-3.1-405b-instruct",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      temperature=0,
      top_p=0.7,
      max_tokens=1024,
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### OpenAI GPT-4o-mini

# %%
from openai import AsyncOpenAI

# Create async client
client = AsyncOpenAI(
  api_key = "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"
)

async def translate_gpt_4o_mini(source_text):
    completion = await client.chat.completions.create(
      model="gpt-4o-mini",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      temperature=0,
      top_p=0.7,
      max_tokens=1024,
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### OpenAI GPT-4o

# %%
from openai import AsyncOpenAI

# Create async client
client = AsyncOpenAI(
  # api_key = "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"
  api_key="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"
)

async def translate_gpt_4o(source_text):
    completion = await client.chat.completions.create(
      model="gpt-4o",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### OpenAI o1-mini

# %% [markdown]
# o1-mini-2024-09-12

# %%
from openai import AsyncOpenAI

# Create async client
client = AsyncOpenAI(
  # api_key = "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"
  api_key="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"
)

async def translate_o1_mini(source_text):
    completion = await client.chat.completions.create(
      model="o1-mini",
      messages=[
          {"role":"user","content":"Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
      ],
      stream=False
    )
    return completion.choices[0].message.content

# %% [markdown]
# ### Cohere Aya 8B

# %%
import cohere
co = cohere.ClientV2("ykmOp5UdjT9xN7wgFRK0Tq3tqvQxhyErd2emt941")

def translate_cohere_aya_8B(source_text):
    response = co.chat(
        model="c4ai-aya-expanse-8b", 
        messages=[{"role": "user", "content": "Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}]
    )
    return response.message.content[0].text

# %%
translate_cohere_aya_8B("Iya bener, deknen lagi jaga warung.")
# Out:
# 'Iya, benar, dia lagi jaga warung.'

# %% [markdown]
# ### Cohere Aya 32B

# %%
import cohere
co = cohere.ClientV2("ykmOp5UdjT9xN7wgFRK0Tq3tqvQxhyErd2emt941")

def translate_cohere_aya_32B(source_text):
    response = co.chat(
        model="c4ai-aya-expanse-32b", 
        messages=[{"role": "user", "content": "Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}]
    )
    return response.message.content[0].text

# %%
translate_cohere_aya_32B("Iya bener, deknen lagi jaga warung.")
# Out:
# 'Iya benar, adikku sedang menjaga warung.'

# %%
import asyncio
async def process_translations():
    # Create lists to store our data
    javanese_texts = []
    ground_truth_translations = []
    translation_tasks = []

    # Create tasks for all translations
    translation_pairs = list(load_translation_pairs())
    
    # Store source texts and ground truth
    for pair in translation_pairs:
        javanese_texts.append(pair['source'])
        ground_truth_translations.append(pair['target'])
        # Create task for translation
        translation_tasks.append(translate_llama_405B(pair['source']))
    
    # Run all translations concurrently
    generated_translations = await asyncio.gather(*translation_tasks)

    # Create a DataFrame
    results_df = pd.DataFrame({
        'javanese': javanese_texts,
        'ground_truth': ground_truth_translations,
        'generated': generated_translations
    })

    # Save to CSV
    results_df.to_csv('translation_results_llama_3.1_405B.csv', index=False)

    # Display first few rows
    print(results_df.head())

# Run the async code
await process_translations()
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# /var/folders/v8/kvhjgvyx233_y8gz7dxb4pbc0000gn/T/ipykernel_79939/1173805511.py in <cell line: 1>()
#      33
#      34 # Run the async code
# ---> 35 await process_translations()
#
# /var/folders/v8/kvhjgvyx233_y8gz7dxb4pbc0000gn/T/ipykernel_79939/1173805511.py in process_translations()
#      17
#      18     # Run all translations concurrently
# ---> 19     generated_translations = await asyncio.gather(*translation_tasks)
#      20
#      21     # Create a DataFrame
#
# /var/folders/v8/kvhjgvyx233_y8gz7dxb4pbc0000gn/T/ipykernel_79939/2045983432.py in translate_llama_405B(source_text)
#       8
#       9 async def translate_llama_405B(source_text):
# ---> 10     completion = await client.chat.completions.create(
#      11       model="meta/llama-3.1-405b-instruct",
#      12       messages=[
#
# ...

# %%
# Create lists to store our data
javanese_texts = []
ground_truth_translations = []
generated_translations = []

# Iterate through the translation pairs
translation_pairs = load_translation_pairs()
for pair in translation_pairs:
    javanese = pair['source']
    ground_truth = pair['target']
    
    # Get the model's translation
    generated = translate_cohere_aya_32B(javanese)
    
    # Store all texts
    javanese_texts.append(javanese)
    ground_truth_translations.append(ground_truth)
    generated_translations.append(generated)

# Create a DataFrame
results_df = pd.DataFrame({
    'javanese': javanese_texts,
    'ground_truth': ground_truth_translations,
    'generated': generated_translations
})

# Save to CSV
results_df.to_csv('translation_results_cohere_aya_32B.csv', index=False)

# Display first few rows
print(results_df.head())
# Out:
#                                             javanese  \
# 0  Cepak saka hotelku nginep, namung digawa mlaku...
# 1                Iya bener, deknen lagi jaga warung.
# 2  Kangkunge lumayan nanging yuyu saus padange ng...
# 3  Manggon nang braga city walk sing sak gedung k...
# 4  Gianyar nompo bantuan sosial 2018 gedene rp 44...
#
#                                         ground_truth  \
# 0  Dekat dengan hotel saya menginap, hanya ditemp...
# 1                 Iya benar, dia sedang jaga warung.
# 2  Kangkungnya lumayan tapi kepiting saus padangn...
# 3  Bertempat di braga city walk yang satu gedung ...
# 4  Gianyar terima bantuan sosial 2018 sebesar rp ...
#
#                                            generated
# 0  Dekat dari hotel tempat saya menginap, ada ban...
# 1           Iya benar, adikku sedang menjaga warung.
# 2  Kangkungnya lumayan enak, tetapi sayangnya ika...
# 3  Saya sangat merekomendasikan tempat ini untuk ...
# 4  Gianyar menerima bantuan sosial sebesar Rp 44,...

# %%
# Save to CSV
results_df.to_csv('translation_results.csv', index=False)

# Display first few rows
print(results_df.head())
# Out:
#                                             javanese  \
# 0  Cepak saka hotelku nginep, namung digawa mlaku...
# 1                Iya bener, deknen lagi jaga warung.
# 2  Kangkunge lumayan nanging yuyu saus padange ng...
# 3  Manggon nang braga city walk sing sak gedung k...
# 4  Gianyar nompo bantuan sosial 2018 gedene rp 44...
#
#                                         ground_truth  \
# 0  Dekat dengan hotel saya menginap, hanya ditemp...
# 1                 Iya benar, dia sedang jaga warung.
# 2  Kangkungnya lumayan tapi kepiting saus padangn...
# 3  Bertempat di braga city walk yang satu gedung ...
# 4  Gianyar terima bantuan sosial 2018 sebesar rp ...
#
#                                            generated
# 0  Cepak saka hotelku nginep, namung digawa mlaku...
# 1                 Iya bener, deket lagi jaga warung.
# 2  Kangkunge lumayan nanging yuyu saus padange ng...
# 3  Manggon nang braga city walk sing sak gedung k...
# 4    Gianyar nompo bantuan sosial 2018 Rp 44.000.000

# %% [markdown]
# ### OpenAI

# %% [markdown]
# ### DeepSeek R1

# %%
from openai import OpenAI

client = OpenAI(api_key="sk-e2c3359cc10d444db8ff32e38fcd5e9d", base_url="https://api.deepseek.com")

def translate_deepseek_r1(source_text):
    response = client.chat.completions.create(
        model="deepseek-reasoner",
        messages=[
        {"role": "user", "content": "Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
    ],
    stream=False
    )
    return response.choices[0].message.content

# %%
translate_deepseek_r1("Iya bener, deknen lagi jaga warung.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/v8/kvhjgvyx233_y8gz7dxb4pbc0000gn/T/ipykernel_79939/1344861238.py in <cell line: 0>()
# ----> 1 translate_deepseek_r1("Iya bener, deknen lagi jaga warung.")
#
# /var/folders/v8/kvhjgvyx233_y8gz7dxb4pbc0000gn/T/ipykernel_79939/3834135601.py in translate_deepseek_r1(source_text)
#       4
#       5 def translate_deepseek_r1(source_text):
# ----> 6     response = client.chat.completions.create(
#       7         model="deepseek-reasoner",
#       8         messages=[
#
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     275                         msg = f"Missing required argument: {quote(missing[0])}"
#     276                 raise TypeError(msg)
# --> 277             return func(*args, **kwargs)
#     278
# ...

# %%
import requests

def translate_deepseek(source_text):
    url = "https://api.deepseek.com/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer sk-e2c3359cc10d444db8ff32e38fcd5e9d"  # your DeepSeek API key
    }
    data = {
        "model": "deepseek-reasoner",
        "messages": [
            {"role": "user", "content": "Translate the following text from Javanese to Indonesian. Return only the translated text: " + source_text}
        ],
        "stream": False
    }
    
    response = requests.post(url, headers=headers, json=data)
    response.raise_for_status()  # Raise exception for bad status codes
    return response.json()

# %%
translate_deepseek("Iya bener, deknen lagi jaga warung.")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ...

# %%
import asyncio
async def process_translations():
    # Create lists to store our data
    javanese_texts = []
    ground_truth_translations = []
    translation_tasks = []

    # Create tasks for all translations
    translation_pairs = list(load_translation_pairs())
    
    # Store source texts and ground truth
    for pair in translation_pairs:
        javanese_texts.append(pair['source'])
        ground_truth_translations.append(pair['target'])
        # Create task for translation
        translation_tasks.append(translate_deepseek(pair['source']))
    
    # Run all translations concurrently
    generated_translations = await asyncio.gather(*translation_tasks)

    # Create a DataFrame
    results_df = pd.DataFrame({
        'javanese': javanese_texts,
        'ground_truth': ground_truth_translations,
        'generated': generated_translations
    })

    # Save to CSV
    results_df.to_csv('translation_results_deepseek.csv', index=False)

    # Display first few rows
    print(results_df.head())

# Run the async code
await process_translations()

# %%
# !pip install azure-ai-inference
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.0/123.0 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 17.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.29.7
#     Uninstalling azure-core-1.29.7:
#       Successfully uninstalled azure-core-1.29.7
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# pip install azure-ai-inference
import os
from azure.ai.inference import ChatCompletionsClient
from azure.core.credentials import AzureKeyCredential

api_key = os.getenv("AZURE_INFERENCE_CREDENTIAL", 'B5t0gnSbsVGPIqpjoQakVsENjU5pHuu2')
if not api_key:
  raise Exception("A key should be provided to invoke the endpoint")

client = ChatCompletionsClient(
    endpoint='https://DeepSeek-R1-abvxt.eastus.models.ai.azure.com',
    credential=AzureKeyCredential(api_key)
)

model_info = client.get_model_info()
print("Model name:", model_info.model_name)
print("Model type:", model_info.model_type)
print("Model provider name:", model_info.model_provider_name)

payload = {
  "messages": [
    {
      "role": "user",
      "content": "Translate the following text from Javanese to Indonesian. Return only the translated text: Iya bener, deknen lagi jaga warung."
    }
  ],
  "max_tokens": 2048
}
response = client.complete(payload)

print("Response:", response.choices[0].message.content)
print("Model:", response.model)
print("Usage:")
print("	Prompt tokens:", response.usage.prompt_tokens)
print("	Total tokens:", response.usage.total_tokens)
print("	Completion tokens:", response.usage.completion_tokens)
# Out:
# Model name: DeepSeek-R1
# Model type: chat-completion
# Model provider name: DeepSeek
# Response: <think>
# Okay, I need to translate the Javanese text "Iya bener, deknen lagi jaga warung." into Indonesian. Let me start by analyzing each part.
#
# First, "Iya bener" – in Javanese, "iya" is "yes" and "bener" means "true" or "correct". In Indonesian, "iya benar" seems to be the direct translation. That part is straightforward.
#
# ...
